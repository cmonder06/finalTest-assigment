# %% [markdown]
# # H1 My Jupyter Notebook on Studio

# %% [markdown]
# **Carol Onderak**
# Clinical Data Analyst

# %% [markdown]
# *I had an interest in programing after taking a C++ course while seeking my degree. After working in healthcare for a few years I began picking up SQL while working as a team lead with our data collections. I decided that I would get certified in SQL to broaded my knowledge and expland my career path.*

# %% [markdown]
# ###H3 The following cell will be a simple code

# %%
# %%
msg = "hello world"
print(msg)
# Out:
# hello world

# %% [markdown]
# This cell includeds Bulleted list, numbered list and hyperlinks.
#
#
# - Item 1
# - Item 2
# - Item 3
# - Item 4
#
# 1. item 1
# 2. item 2
# 3. item 3
# 4. item 4
#
# This is [Google Search](http://www.google.com)
